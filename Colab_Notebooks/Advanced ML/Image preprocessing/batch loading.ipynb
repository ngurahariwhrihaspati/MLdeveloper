# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist

(training_image, training_labels), (test_image, test_labels) = mnist.load_data()

training_image = training_image / 255.0
test_image = test_image / 255.0

model = tf.keras.models.Sequential([tf.keras.layers.Flatten(input_shape=(28,28)),
                                    tf.keras.layers.Dense(128, activation=tf.nn.relu),
                                    tf.keras.layers.Dense(10, activation=tf.nn.softmax)])

model.compile(optimizer = tf.optimizers.Adam(),
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(training_image, training_labels, batch_size=32, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2562 - accuracy: 0.9273
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1119 - accuracy: 0.9672
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0769 - accuracy: 0.9767
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0574 - accuracy: 0.9824
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0441 - accuracy: 0.9863

# %%
model.fit(training_image, training_labels, batch_size=128, epochs=5)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0233 - accuracy: 0.9941
# Epoch 2/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0187 - accuracy: 0.9959
# Epoch 3/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0168 - accuracy: 0.9961
# Epoch 4/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0148 - accuracy: 0.9973
# Epoch 5/5
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0131 - accuracy: 0.9974

# %%
import math

a = (5*2 + 3*3 + 1*3) / math.sqrt((25+9+1) * (4+9+9))
a
# Out:
# 0.7928249671720918

# %%
b = (3*1 + 2*2) / math.sqrt((9+4) * (1+4))
b
# Out:
# 0.8682431421244593

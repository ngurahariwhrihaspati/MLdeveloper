# %%
! mkdir sentence_dataset

# %%
! unzip sentence_data_set.zip -d sentence_dataset/
# Out:
# unzip:  cannot find or open sentence_data_set.zip, sentence_data_set.zip.zip or sentence_data_set.zip.ZIP.

# %%
import pandas as pd
import os

df = pd.read_csv('yelp_labelled.txt', names=['sentence', 'label'], sep='\t')

# %%
df.tail()
# Out:
#                                               sentence  label
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0

# %%
from sklearn.model_selection import train_test_split
kalimat = df['sentence'].values
y = df['label'].values
kalimat_latih, kalimat_test, y_latih, y_test = train_test_split(kalimat, y, test_size=0.2)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
 
tokenizer = Tokenizer(num_words=250, oov_token='x')
tokenizer.fit_on_texts(kalimat_latih) 
tokenizer.fit_on_texts(kalimat_test)
 
sekuens_latih = tokenizer.texts_to_sequences(kalimat_latih)
sekuens_test = tokenizer.texts_to_sequences(kalimat_test)
 
padded_latih = pad_sequences(sekuens_latih) 
padded_test = pad_sequences(sekuens_test)

print(len(y_latih))
print(padded_latih.shape)
print(len(y_test))
print(padded_test.shape)
# Out:
# 800
# (800, 32)
# 200
# (200, 30)

# %%
import tensorflow as tf
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(250, 16),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
num_epochs = 30
history = model.fit(padded_latih, y_latih, epochs=num_epochs,
                    validation_data=(padded_test, y_test), verbose=2)
# Out:
# Epoch 1/30
# 25/25 - 1s - loss: 0.6930 - accuracy: 0.5100 - val_loss: 0.6927 - val_accuracy: 0.4750 - 723ms/epoch - 29ms/step
# Epoch 2/30
# 25/25 - 0s - loss: 0.6912 - accuracy: 0.5113 - val_loss: 0.6918 - val_accuracy: 0.4750 - 85ms/epoch - 3ms/step
# Epoch 3/30
# 25/25 - 0s - loss: 0.6886 - accuracy: 0.6375 - val_loss: 0.6883 - val_accuracy: 0.6400 - 71ms/epoch - 3ms/step
# Epoch 4/30
# 25/25 - 0s - loss: 0.6834 - accuracy: 0.6687 - val_loss: 0.6832 - val_accuracy: 0.6550 - 74ms/epoch - 3ms/step
# Epoch 5/30
# 25/25 - 0s - loss: 0.6763 - accuracy: 0.6862 - val_loss: 0.6768 - val_accuracy: 0.6750 - 90ms/epoch - 4ms/step
# Epoch 6/30
# 25/25 - 0s - loss: 0.6668 - accuracy: 0.6850 - val_loss: 0.6684 - val_accuracy: 0.6800 - 77ms/epoch - 3ms/step
# Epoch 7/30
# 25/25 - 0s - loss: 0.6535 - accuracy: 0.7163 - val_loss: 0.6565 - val_accuracy: 0.6900 - 74ms/epoch - 3ms/step
# Epoch 8/30
# 25/25 - 0s - loss: 0.6366 - accuracy: 0.7312 - val_loss: 0.6434 - val_accuracy: 0.6850 - 71ms/epoch - 3ms/step
# Epoch 9/30
# 25/25 - 0s - loss: 0.6167 - accuracy: 0.7300 - val_loss: 0.6263 - val_accuracy: 0.6950 - 89ms/epoch - 4ms/step
# Epoch 10/30
# 25/25 - 0s - loss: 0.5915 - accuracy: 0.7650 - val_loss: 0.6071 - val_accuracy: 0.7050 - 73ms/epoch - 3ms/step
# Epoch 11/30
# 25/25 - 0s - loss: 0.5657 - accuracy: 0.7837 - val_loss: 0.5878 - val_accuracy: 0.7400 - 88ms/epoch - 4ms/step
# Epoch 12/30
# 25/25 - 0s - loss: 0.5369 - accuracy: 0.8062 - val_loss: 0.5660 - val_accuracy: 0.7400 - 86ms/epoch - 3ms/step
# Epoch 13/30
# 25/25 - 0s - loss: 0.5114 - accuracy: 0.8138 - val_loss: 0.5563 - val_accuracy: 0.7500 - 84ms/epoch - 3ms/step
# Epoch 14/30
# 25/25 - 0s - loss: 0.4849 - accuracy: 0.8175 - val_loss: 0.5360 - val_accuracy: 0.7550 - 90ms/epoch - 4ms/step
# Epoch 15/30
# 25/25 - 0s - loss: 0.4598 - accuracy: 0.8300 - val_loss: 0.5229 - val_accuracy: 0.7600 - 75ms/epoch - 3ms/step
# Epoch 16/30
# 25/25 - 0s - loss: 0.4368 - accuracy: 0.8325 - val_loss: 0.5052 - val_accuracy: 0.7500 - 73ms/epoch - 3ms/step
# Epoch 17/30
# 25/25 - 0s - loss: 0.4162 - accuracy: 0.8425 - val_loss: 0.4965 - val_accuracy: 0.7550 - 81ms/epoch - 3ms/step
# Epoch 18/30
# 25/25 - 0s - loss: 0.3981 - accuracy: 0.8438 - val_loss: 0.4893 - val_accuracy: 0.7500 - 74ms/epoch - 3ms/step
# Epoch 19/30
# 25/25 - 0s - loss: 0.3832 - accuracy: 0.8512 - val_loss: 0.4803 - val_accuracy: 0.7600 - 92ms/epoch - 4ms/step
# Epoch 20/30
# 25/25 - 0s - loss: 0.3673 - accuracy: 0.8475 - val_loss: 0.4820 - val_accuracy: 0.7600 - 85ms/epoch - 3ms/step
# Epoch 21/30
# 25/25 - 0s - loss: 0.3544 - accuracy: 0.8637 - val_loss: 0.4761 - val_accuracy: 0.7850 - 93ms/epoch - 4ms/step
# Epoch 22/30
# 25/25 - 0s - loss: 0.3468 - accuracy: 0.8612 - val_loss: 0.4708 - val_accuracy: 0.7750 - 74ms/epoch - 3ms/step
# Epoch 23/30
# 25/25 - 0s - loss: 0.3343 - accuracy: 0.8650 - val_loss: 0.4696 - val_accuracy: 0.7850 - 73ms/epoch - 3ms/step
# Epoch 24/30
# 25/25 - 0s - loss: 0.3309 - accuracy: 0.8750 - val_loss: 0.4879 - val_accuracy: 0.7600 - 92ms/epoch - 4ms/step
# Epoch 25/30
# 25/25 - 0s - loss: 0.3211 - accuracy: 0.8750 - val_loss: 0.4710 - val_accuracy: 0.7800 - 79ms/epoch - 3ms/step
# Epoch 26/30
# 25/25 - 0s - loss: 0.3123 - accuracy: 0.8637 - val_loss: 0.4704 - val_accuracy: 0.7800 - 86ms/epoch - 3ms/step
# Epoch 27/30
# 25/25 - 0s - loss: 0.3067 - accuracy: 0.8737 - val_loss: 0.4707 - val_accuracy: 0.7850 - 88ms/epoch - 4ms/step
# Epoch 28/30
# 25/25 - 0s - loss: 0.2992 - accuracy: 0.8750 - val_loss: 0.4742 - val_accuracy: 0.7800 - 80ms/epoch - 3ms/step
# Epoch 29/30
# 25/25 - 0s - loss: 0.2986 - accuracy: 0.8800 - val_loss: 0.4783 - val_accuracy: 0.7800 - 87ms/epoch - 3ms/step
# Epoch 30/30
# 25/25 - 0s - loss: 0.2886 - accuracy: 0.8825 - val_loss: 0.4806 - val_accuracy: 0.7900 - 79ms/epoch - 3ms/step
